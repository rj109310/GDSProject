# %%
import pandas as pd
df = pd.read_csv("./FPData2.csv")
df.head()
df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.350           0.451
# 1     Afghanistan  2009        4.402               7.509           0.552
# 2     Afghanistan  2010        4.758               7.614           0.539
# 3     Afghanistan  2011        3.832               7.581           0.521
# 4     Afghanistan  2012        3.783               7.661           0.521
# ...           ...   ...          ...                 ...             ...
# 2194     Zimbabwe  2018        3.616               7.783           0.775
# 2195     Zimbabwe  2019        2.694               7.698           0.759
# 2196     Zimbabwe  2020        3.160               7.596           0.717
# 2197     Zimbabwe  2021        3.155               7.657           0.685
# 2198     Zimbabwe  2022        3.296               7.670           0.666
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df.columns = ['Country', 'year', 'ladder', 'gdp', 'support', 'life_expec', 'freedom', 'generosity','corruption','positive', 'negative']
df.head()
# Out:
#        Country  year  ladder    gdp  support  life_expec  freedom  generosity  \
# 0  Afghanistan  2008   3.724  7.350    0.451        50.5    0.718       0.168
# 1  Afghanistan  2009   4.402  7.509    0.552        50.8    0.679       0.191
# 2  Afghanistan  2010   4.758  7.614    0.539        51.1    0.600       0.121
# 3  Afghanistan  2011   3.832  7.581    0.521        51.4    0.496       0.164
# 4  Afghanistan  2012   3.783  7.661    0.521        51.7    0.531       0.238
#
#    corruption  positive  negative
# 0       0.882     0.414     0.258
# 1       0.850     0.481     0.237
# 2       0.707     0.517     0.275
# 3       0.731     0.480     0.267
# 4       0.776     0.614     0.268

# %%
y = df.groupby('Country').count()
less = y[y['year'] <= 10].index.tolist()
df_update = df[~df['Country'].isin(less)]

# %%
df_update.groupby('Country').count()
# Out:
#              year  ladder  gdp  support  life_expec  freedom  generosity  \
# Country
# Afghanistan    14      14   13       14          14       14          13
# Albania        15      15   15       15          15       15          15
# Argentina      17      17   17       17          17       17          17
# Armenia        16      16   16       16          16       16          16
# Australia      16      16   16       16          16       16          15
# ...           ...     ...  ...      ...         ...      ...         ...
# Venezuela      17      17   14       17          17       17          13
# Vietnam        17      17   17       16          17       14          16
# Yemen          12      12   12       12          12       12          12
# Zambia         15      15   15       15          15       15          15
# Zimbabwe       17      17   17       17          17       17          17
#
#              corruption  positive  negative
# Country
# ...

# %%
df_update.groupby('year').size()
# Out:
# year
# 2005     27
# 2006     84
# 2007     95
# 2008    102
# 2009    105
# 2010    115
# 2011    126
# 2012    126
# 2013    126
# 2014    128
# 2015    129
# 2016    128
# 2017    129
# 2018    126
# 2019    127
# 2020    108
# 2021    114
# 2022    104
# dtype: int64

# %%
df_means = df_update.groupby(['year']).mean()
df_means
# Out:
# <ipython-input-7-e56f6312bb02>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_means = df_update.groupby(['year']).mean()
#         ladder        gdp   support  life_expec   freedom  generosity  \
# year
# 2005  6.446259  10.124222  0.897407   66.825926  0.829520    0.248000
# 2006  5.183274   9.086929  0.832560   60.138313  0.732753   -0.005519
# 2007  5.445011   9.272213  0.812516   62.240181  0.683809    0.002489
# 2008  5.437627   9.243265  0.789931   61.444550  0.688010    0.009416
# 2009  5.510524   9.343324  0.822260   62.913515  0.690192   -0.011057
# 2010  5.557835   9.466817  0.834868   63.302212  0.709632    0.002078
# 2011  5.488667   9.398849  0.811698   62.890164  0.737690   -0.023160
# 2012  5.481381   9.455508  0.812452   63.331639  0.715413   -0.013134
# ...

# %%
df_means1 = df_means.drop([2005])
df_means2 = df_means1.drop([2006])
df_means3 = df_means2.drop([2007])
df_means4 = df_means3.drop([2008])
df_means5 = df_means4.drop([2009])
df_means6 = df_means5.drop([2010])
df_means7 = df_means6.drop([2020])
df_means8 = df_means7.drop([2021])
df_means9 = df_means8.drop([2022])
df_means9
# Out:
#         ladder       gdp   support  life_expec   freedom  generosity  \
# year
# 2011  5.488667  9.398849  0.811698   62.890164  0.737690   -0.023160
# 2012  5.481381  9.455508  0.812452   63.331639  0.715413   -0.013134
# 2013  5.423857  9.427659  0.807563   63.336911  0.730512   -0.016545
# 2014  5.457617  9.478563  0.812656   63.750806  0.740268    0.011920
# 2015  5.455302  9.463225  0.804659   63.935714  0.749504    0.006000
# 2016  5.470797  9.479031  0.819320   64.102016  0.763567   -0.010406
# 2017  5.551969  9.487597  0.811461   64.324800  0.783023   -0.015164
# 2018  5.594611  9.484349  0.817214   64.469309  0.785512   -0.038651
# 2019  5.630827  9.536504  0.819031   64.792683  0.798897   -0.032764
#
#       corruption  positive  negative
# year
# 2011    0.757380  0.637595  0.250460
# 2012    0.761700  0.643992  0.258619
# 2013    0.761375  0.656798  0.269627
# 2014    0.736760  0.657573  0.268872
# 2015    0.742787  0.661085  0.273465
# ...

# %%
x_labels = [2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
#Plotting the means for each year, removing 2005, due to missing data
fig, axs = plt.subplots(2, 4, figsize=(14,8))
axs[0, 0].plot(x_labels, df_means9['ladder'])
axs[0, 0].set_title('Ladder')
axs[0, 1].plot(x_labels, df_means9['generosity'])
axs[0, 1].set_title('Generosity')
axs[1, 0].plot(x_labels, df_means9['life_expec'])
axs[1, 0].set_title('Life Expectency')
axs[1, 1].plot(x_labels, df_means9['freedom'])
axs[1, 1].set_title('Freedom')
axs[0, 2].plot(x_labels, df_means9['support'])
axs[0, 2].set_title('Social Support')
axs[0, 3].plot(x_labels, df_means9['corruption'])
axs[0, 3].set_title('Corruption')
axs[1, 2].plot(x_labels, df_means9['positive'])
axs[1, 2].set_title('Positive Affect')
axs[1, 3].plot(x_labels, df_means9['negative'])
axs[1, 3].set_title('Negative Affect')
# Out:
# Text(0.5, 1.0, 'Negative Affect')

# %%
#plotting with every year

# %%
x_labels2 = [2005,2006,2007,2008,2009,2010,2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,2020,2021,2022]
#Plotting the means for each year, removing 2005, due to missing data
fig, axs = plt.subplots(2, 4, figsize=(14,8))
axs[0, 0].plot(x_labels2, df_means['ladder'])
axs[0, 0].set_title('Ladder')
axs[0, 1].plot(x_labels2, df_means['generosity'])
axs[0, 1].set_title('Generosity')
axs[1, 0].plot(x_labels2, df_means['life_expec'])
axs[1, 0].set_title('Life Expectency')
axs[1, 1].plot(x_labels2, df_means['freedom'])
axs[1, 1].set_title('Freedom')
axs[0, 2].plot(x_labels2, df_means['support'])
axs[0, 2].set_title('Social Support')
axs[0, 3].plot(x_labels2, df_means['corruption'])
axs[0, 3].set_title('Corruption')
axs[1, 2].plot(x_labels2, df_means['positive'])
axs[1, 2].set_title('Positive Affect')
axs[1, 3].plot(x_labels2, df_means['negative'])
axs[1, 3].set_title('Negative Affect')
# Out:
# Text(0.5, 1.0, 'Negative Affect')

# %%
#DROPPING ALL BAD YEARS FROM DATAFRAME
year_list = range(2011, 2020)
df_11 = df_update[df_update['year'].isin(year_list)]
df_11
# Out:
#           Country  year  ladder    gdp  support  life_expec  freedom  \
# 3     Afghanistan  2011   3.832  7.581    0.521      51.400    0.496
# 4     Afghanistan  2012   3.783  7.661    0.521      51.700    0.531
# 5     Afghanistan  2013   3.572  7.680    0.484      52.000    0.578
# 6     Afghanistan  2014   3.131  7.671    0.526      52.300    0.509
# 7     Afghanistan  2015   3.983  7.654    0.529      52.600    0.389
# ...           ...   ...     ...    ...      ...         ...      ...
# 2191     Zimbabwe  2015   3.703  7.747    0.736      51.200    0.667
# 2192     Zimbabwe  2016   3.735  7.735    0.768      51.675    0.733
# 2193     Zimbabwe  2017   3.638  7.754    0.754      52.150    0.753
# 2194     Zimbabwe  2018   3.616  7.783    0.775      52.625    0.763
# 2195     Zimbabwe  2019   2.694  7.698    0.759      53.100    0.632
#
#       generosity  corruption  positive  negative
# 3          0.164       0.731     0.480     0.267
# ...

# %%
df_11.groupby('year').count()
# Out:
#       Country  ladder  gdp  support  life_expec  freedom  generosity  \
# year
# 2011      126     126  126      126         122      126         125
# 2012      126     126  126      126         122      126         119
# 2013      126     126  126      126         123      125         123
# 2014      128     128  128      125         124      123         125
# 2015      129     129  129      129         126      127         129
# 2016      128     128  128      128         124      127         128
# 2017      129     129  129      128         125      128         128
# 2018      126     126  126      126         123      125         126
# 2019      127     127  127      127         123      126         127
#
#       corruption  positive  negative
# year
# 2011         121       126       126
# 2012         120       126       126
# 2013         120       124       126
# 2014         121       124       125
# 2015         122       129       129
# ...

# %%
df_11.groupby('Country').count()
# Out:
#              year  ladder  gdp  support  life_expec  freedom  generosity  \
# Country
# Afghanistan     9       9    9        9           9        9           9
# Albania         9       9    9        9           9        9           9
# Argentina       9       9    9        9           9        9           9
# Armenia         9       9    9        9           9        9           9
# Australia       9       9    9        9           9        9           9
# ...           ...     ...  ...      ...         ...      ...         ...
# Venezuela       9       9    9        9           9        9           9
# Vietnam         9       9    9        8           9        6           8
# Yemen           9       9    9        9           9        9           9
# Zambia          9       9    9        9           9        9           9
# Zimbabwe        9       9    9        9           9        9           9
#
#              corruption  positive  negative
# Country
# ...

# %%
y1 = df_11.groupby('Country').count()
less = y1[y1['year'] <= 8].index.tolist()
df_update1 = df_11[~df_11['Country'].isin(less)]

# %%
df_update1
# Out:
#           Country  year  ladder    gdp  support  life_expec  freedom  \
# 3     Afghanistan  2011   3.832  7.581    0.521      51.400    0.496
# 4     Afghanistan  2012   3.783  7.661    0.521      51.700    0.531
# 5     Afghanistan  2013   3.572  7.680    0.484      52.000    0.578
# 6     Afghanistan  2014   3.131  7.671    0.526      52.300    0.509
# 7     Afghanistan  2015   3.983  7.654    0.529      52.600    0.389
# ...           ...   ...     ...    ...      ...         ...      ...
# 2191     Zimbabwe  2015   3.703  7.747    0.736      51.200    0.667
# 2192     Zimbabwe  2016   3.735  7.735    0.768      51.675    0.733
# 2193     Zimbabwe  2017   3.638  7.754    0.754      52.150    0.753
# 2194     Zimbabwe  2018   3.616  7.783    0.775      52.625    0.763
# 2195     Zimbabwe  2019   2.694  7.698    0.759      53.100    0.632
#
#       generosity  corruption  positive  negative
# 3          0.164       0.731     0.480     0.267
# ...

# %%
df_update1.groupby('Country').count()
# Out:
#              year  ladder  gdp  support  life_expec  freedom  generosity  \
# Country
# Afghanistan     9       9    9        9           9        9           9
# Albania         9       9    9        9           9        9           9
# Argentina       9       9    9        9           9        9           9
# Armenia         9       9    9        9           9        9           9
# Australia       9       9    9        9           9        9           9
# ...           ...     ...  ...      ...         ...      ...         ...
# Venezuela       9       9    9        9           9        9           9
# Vietnam         9       9    9        8           9        6           8
# Yemen           9       9    9        9           9        9           9
# Zambia          9       9    9        9           9        9           9
# Zimbabwe        9       9    9        9           9        9           9
#
#              corruption  positive  negative
# Country
# ...
